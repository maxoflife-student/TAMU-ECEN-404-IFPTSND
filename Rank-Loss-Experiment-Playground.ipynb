# %%
# Ignore cuDDa warning messages
import warnings
warnings.filterwarnings('ignore')

# Enable GPU
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# Expands the Jupyter Notebook Output Size to fit your window
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

from tensorflow_models import TF_Models, Ein_Multiply, leaky_relu, rank_loss_func
DMJ = TF_Models('./data_sets/NASDAQ_Cleaned', './models', reload=False)
data_splits = DMJ.split_data()
model = DMJ.generate_model()
# Out:
# <style>.container { width:100% !important; }</style>
# GridBox(children=(Dropdown(description='Model Types:', options=('lstm', 'lstm_gcn_1', 'lstm_gcn_2', 'lstm_gcn_…
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 1239, 5)]         0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 1239, 64)          17920
# _________________________________________________________________
# dropout (Dropout)            (None, 1239, 64)          0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 64)                33024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 51,009
# Trainable params: 51,009
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Setting an epoch and learning rate that will not train between experiments
model = DMJ.train_model(epochs=10, learning_rate=1e-5)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 0s 98ms/step - loss: 0.1205 - val_loss: 0.0593
# Epoch 2/10
# 1/1 [==============================] - 0s 80ms/step - loss: 0.1298 - val_loss: 0.0590
# Epoch 3/10
# 1/1 [==============================] - 0s 79ms/step - loss: 0.1172 - val_loss: 0.0588
# Epoch 4/10
# 1/1 [==============================] - 0s 80ms/step - loss: 0.1177 - val_loss: 0.0586
# Epoch 5/10
# 1/1 [==============================] - 0s 85ms/step - loss: 0.1237 - val_loss: 0.0584
# Epoch 6/10
# 1/1 [==============================] - 0s 81ms/step - loss: 0.1278 - val_loss: 0.0583
# Epoch 7/10
# 1/1 [==============================] - 0s 82ms/step - loss: 0.1292 - val_loss: 0.0583
# Epoch 8/10
# 1/1 [==============================] - 0s 88ms/step - loss: 0.1238 - val_loss: 0.0582
# Epoch 9/10
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1159 - val_loss: 0.0582
# Epoch 10/10
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1141 - val_loss: 0.0582

# %%
# Saving the model
DMJ.save_model(tag='Y_LABELS_PRICE_ALPHA_0_DROPOUT_80e-2')

# %%
# Generate a prediction class
from graph_predictions import Graph_Predictions
GP = Graph_Predictions("./models", "./strategies", DMJ)

# %%
items = ['01-08-2021--18--50--Y_LABELS_PRICE_ALPHA_0_DROPOUT_80e-2}--75Epochs--rlf-Loss--64-HU--',
        ]

# Generate prediction files
for item in items:
    GP.generate_prediction_json(item, neural_net_type='lstm')
# Out:
# Loading Model: '01-08-2021--18--50--Y_LABELS_PRICE_ALPHA_0_DROPOUT_80e-2}--75Epochs--rlf-Loss--64-HU--'
# Total number of days: 309
# Day 1 | Day 2 | Day 3 | Day 4 | Day 5 | Day 6 | Day 7 | Day 8 | Day 9 | Day 10 | Day 11 | Day 12 | Day 13 | Day 14 | Day 15 | Day 16 | Day 17 | Day 18 | Day 19 | Day 20 | Day 21 | Day 22 | Day 23 | Day 24 | Day 25 | Day 26 | Day 27 | Day 28 | Day 29 | Day 30 | Day 31 | Day 32 | Day 33 | Day 34 | Day 35 | Day 36 | Day 37 | Day 38 | Day 39 | Day 40 | Day 41 | Day 42 | Day 43 | Day 44 | Day 45 | Day 46 | Day 47 | Day 48 | Day 49 | Day 50 | Day 51 | Day 52 | Day 53 | Day 54 | Day 55 | Day 56 | Day 57 | Day 58 | Day 59 | Day 60 | Day 61 | Day 62 | Day 63 | Day 64 | Day 65 | Day 66 | Day 67 | Day 68 | Day 69 | Day 70 | Day 71 | Day 72 | Day 73 | Day 74 | Day 75 | Day 76 | Day 77 | Day 78 | Day 79 | Day 80 | Day 81 | Day 82 | Day 83 | Day 84 | Day 85 | Day 86 | Day 87 | Day 88 | Day 89 | Day 90 | Day 91 | Day 92 | Day 93 | Day 94 | Day 95 | Day 96 | Day 97 | Day 98 | Day 99 | Day 100 | Day 101 | Day 102 | Day 103 | Day 104 | Day 105 | Day 106 | Day 107 | Day 108 | Day 109 | Day 110 | Day 111 | Day 112 | Day 113 | Day 114 | Day 115 | Day 116 | Day 117 | Day 118 | Day 119 | Day 120 | Day 121 | Day 122 | Day 123 | Day 124 | Day 125 | Day 126 | Day 127 | Day 128 | Day 129 | Day 130 | Day 131 | Day 132 | Day 133 | Day 134 | Day 135 | Day 136 | Day 137 | Day 138 | Day 139 | Day 140 | Day 141 | Day 142 | Day 143 | Day 144 | Day 145 | Day 146 | Day 147 | Day 148 | Day 149 | Day 150 | Day 151 | Day 152 | Day 153 | Day 154 | Day 155 | Day 156 | Day 157 | Day 158 | Day 159 | Day 160 | Day 161 | Day 162 | Day 163 | Day 164 | Day 165 | Day 166 | Day 167 | Day 168 | Day 169 | Day 170 | Day 171 | Day 172 | Day 173 | Day 174 | Day 175 | Day 176 | Day 177 | Day 178 | Day 179 | Day 180 | Day 181 | Day 182 | Day 183 | Day 184 | Day 185 | Day 186 | Day 187 | Day 188 | Day 189 | Day 190 | Day 191 | Day 192 | Day 193 | Day 194 | Day 195 | Day 196 | Day 197 | Day 198 | Day 199 | Day 200 | Day 201 | Day 202 | Day 203 | Day 204 | Day 205 | Day 206 | Day 207 | Day 208 | Day 209 | Day 210 | Day 211 | Day 212 | Day 213 | Day 214 | Day 215 | Day 216 | Day 217 | Day 218 | Day 219 | Day 220 | Day 221 | Day 222 | Day 223 | Day 224 | Day 225 | Day 226 | Day 227 | Day 228 | Day 229 | Day 230 | Day 231 | Day 232 | Day 233 | Day 234 | Day 235 | Day 236 | Day 237 | Day 238 | Day 239 | Day 240 | Day 241 | Day 242 | Day 243 | Day 244 | Day 245 | Day 246 | Day 247 | Day 248 | Day 249 | Day 250 | Day 251 | Day 252 | Day 253 | Day 254 | Day 255 | Day 256 | Day 257 | Day 258 | Day 259 | Day 260 | Day 261 | Day 262 | Day 263 | Day 264 | Day 265 | Day 266 | Day 267 | Day 268 | Day 269 | Day 270 | Day 271 | Day 272 | Day 273 | Day 274 | Day 275 | Day 276 | Day 277 | Day 278 | Day 279 | Day 280 | Day 281 | Day 282 | Day 283 | Day 284 | Day 285 | Day 286 | Day 287 | Day 288 | Day 289 | Day 290 | Day 291 | Day 292 | Day 293 | Day 294 | Day 295 | Day 296 | Day 297 | Day 298 | Day 299 | Day 300 | Day 301 | Day 302 | Day 303 | Day 304 | Day 305 | Day 306 | Day 307 |

# %%
avg = [1, 50, 200]
avg = [1]
for a in avg:
    for item in items:
        GP.prediction_json_strategy(item + '_PM', average=a, avoid_fall=True, name_override=item + f'_PM_{a}AVG_AvoidFall')
# Out:
# Loading PM Model: '01-08-2021--18--50--Y_LABELS_PRICE_ALPHA_0_DROPOUT_80e-2}--75Epochs--rlf-Loss--64-HU--_PM'
# Day: 1		Total: 50000 Buying: ['VCSH']
# Day: 2		Total: 49994 Buying: ['VMBS']
# Day: 3		Total: 49998 Buying: ['VCSH']
# Day: 4		Total: 49994 Buying: ['VMBS']
# Day: 5		Total: 49998 Buying: ['VCSH']
# Day: 6		Total: 49996 Buying: ['VMBS']
# Day: 7		Total: 50001 Buying: ['VMBS']
# Day: 8		Total: 50014 Buying: ['VMBS']
# Day: 9		Total: 50045 Buying: ['VMBS']
# Day: 10		Total: 50077 Buying: ['VMBS']
# Day: 11		Total: 50103 Buying: ['VMBS']
# Day: 12		Total: 50110 Buying: ['VMBS']
# Day: 13		Total: 50121 Buying: ['VGSH']
# Day: 14		Total: 50107 Buying: ['VCSH']
# Day: 15		Total: 50090 Buying: ['VCIT']
# Day: 16		Total: 50048 Buying: ['VGIT']
# Day: 17		Total: 49952 Buying: ['VTIP']
# Day: 18		Total: 49869 Buying: ['VCLT']
# Day: 19		Total: 49863 Buying: ['ORLY']
# Day: 20		Total: 49839 Buying: ['VMBS']
# Day: 21		Total: 49890 Buying: ['VGSH']
# Day: 22		Total: 49872 Buying: ['VCSH']
# Day: 23		Total: 49870 Buying: ['VMBS']
# Day: 24		Total: 49877 Buying: ['VMBS']
# Day: 25		Total: 49886 Buying: ['VMBS']
# Day: 26		Total: 49903 Buying: ['VMBS']
# Day: 27		Total: 49916 Buying: ['VMBS']
# Day: 28		Total: 49929 Buying: ['VMBS']
# Day: 29		Total: 49940 Buying: ['VGSH']
# Day: 30		Total: 49939 Buying: ['VCSH']
# Day: 31		Total: 49934 Buying: ['VCIT']
# Day: 32		Total: 49915 Buying: ['VTIP']
# Day: 33		Total: 49834 Buying: ['VMBS']
# Day: 34		Total: 49840 Buying: ['VGSH']
# Day: 35		Total: 49814 Buying: ['VMBS']
# Day: 36		Total: 49821 Buying: ['VGSH']
# Day: 37		Total: 49815 Buying: ['VMBS']
# Day: 38		Total: 49827 Buying: ['VMBS']
# Day: 39		Total: 49827 Buying: ['VMBS']
# Day: 40		Total: 49834 Buying: ['VGSH']
# Day: 41		Total: 49772 Buying: ['VCSH']
# Day: 42		Total: 49749 Buying: ['VCIT']
# Day: 43		Total: 49672 Buying: ['VTIP']
# Day: 44		Total: 49440 Buying: ['VGIT']
# Day: 45		Total: 49393 Buying: ['VCLT']
# Day: 46		Total: 49305 Buying: ['PROV']
# Day: 47		Total: 49122 Buying: ['PROV']
# Day: 48		Total: 49097 Buying: ['VGSH']
# Day: 49		Total: 49198 Buying: ['VMBS']
# Day: 50		Total: 49190 Buying: ['VCSH']
# Day: 51		Total: 49099 Buying: ['VTIP']
# Day: 52		Total: 49076 Buying: ['VCIT']
# Day: 53		Total: 49068 Buying: ['VGSH']
# Day: 54		Total: 49084 Buying: ['VMBS']
# Day: 55		Total: 49078 Buying: ['VCSH']
# Day: 56		Total: 49046 Buying: ['VTIP']
# Day: 57		Total: 49044 Buying: ['VGSH']
# Day: 58		Total: 49073 Buying: ['VMBS']
# Day: 59		Total: 49069 Buying: ['VCSH']
# Day: 60		Total: 49069 Buying: ['VGSH']
# Day: 61		Total: 49102 Buying: ['VCSH']
# Day: 62		Total: 49097 Buying: ['VMBS']
# Day: 63		Total: 49093 Buying: ['VTIP']
# Day: 64		Total: 49074 Buying: ['PROV']
# Day: 65		Total: 48961 Buying: ['VGSH']
# Day: 66		Total: 48971 Buying: ['VCSH']
# Day: 67		Total: 48951 Buying: ['VTIP']
# Day: 68		Total: 48929 Buying: ['VMBS']
# Day: 69		Total: 48820 Buying: ['PROV']
# Day: 70		Total: 48794 Buying: ['EGOV']
# Day: 71		Total: 48724 Buying: ['SBSI']
# Day: 72		Total: 48324 Buying: ['VGSH']
# Day: 73		Total: 48409 Buying: ['PROV']
# Day: 74		Total: 48406 Buying: ['VGSH']
# Day: 75		Total: 48450 Buying: ['VGSH']
# Day: 76		Total: 48495 Buying: ['VGSH']
# Day: 77		Total: 48498 Buying: ['VGSH']
# Day: 78		Total: 48511 Buying: ['VGSH']
# Day: 79		Total: 48528 Buying: ['VGSH']
# Day: 80		Total: 48531 Buying: ['PROV']
# Day: 81		Total: 48503 Buying: ['VCSH']
# Day: 82		Total: 48197 Buying: ['VGSH']
# Day: 83		Total: 48215 Buying: ['VGSH']
# Day: 84		Total: 48217 Buying: ['VGSH']
# Day: 85		Total: 48218 Buying: ['VGSH']
# Day: 86		Total: 48228 Buying: ['VGSH']
# Day: 87		Total: 48228 Buying: ['PROV']
# Day: 88		Total: 48223 Buying: ['VCSH']
# Day: 89		Total: 47909 Buying: ['VGSH']
# Day: 90		Total: 47930 Buying: ['VCSH']
# Day: 91		Total: 47925 Buying: ['VGSH']
# Day: 92		Total: 47930 Buying: ['VGSH']
# Day: 93		Total: 47937 Buying: ['VGSH']
# Day: 94		Total: 47940 Buying: ['VCSH']
# Day: 95		Total: 47938 Buying: ['VGSH']
# Day: 96		Total: 47951 Buying: ['VGSH']
# Day: 97		Total: 47958 Buying: ['VCSH']
# Day: 98		Total: 47953 Buying: ['RDI']
# Day: 99		Total: 47950 Buying: ['VGSH']
# Day: 100		Total: 48129 Buying: ['VGSH']
# Day: 101		Total: 48134 Buying: ['VGSH']
# Day: 102		Total: 48144 Buying: ['VGSH']
# Day: 103		Total: 48155 Buying: ['VGSH']
# Day: 104		Total: 48163 Buying: ['VCSH']
# Day: 105		Total: 48160 Buying: ['VTIP']
# Day: 106		Total: 48149 Buying: ['RDI']
# Day: 107		Total: 48135 Buying: ['VGSH']
# Day: 108		Total: 48184 Buying: ['VGSH']
# Day: 109		Total: 48185 Buying: ['VGSH']
# Day: 110		Total: 48189 Buying: ['VGSH']
# Day: 111		Total: 48202 Buying: ['VGSH']
# Day: 112		Total: 48220 Buying: ['VGSH']
# Day: 113		Total: 48240 Buying: ['VGSH']
# Day: 114		Total: 48245 Buying: ['VCSH']
# Day: 115		Total: 48243 Buying: ['VTIP']
# Day: 116		Total: 48227 Buying: ['BPOP']
# Day: 117		Total: 48194 Buying: ['VMBS']
# Day: 118		Total: 48089 Buying: ['OZRK']
# Day: 119		Total: 48018 Buying: ['VGSH']
# Day: 120		Total: 48076 Buying: ['VCSH']
# Day: 121		Total: 48064 Buying: ['VTIP']
# Day: 122		Total: 48035 Buying: ['OZRK']
# Day: 123		Total: 48003 Buying: ['PACW']
# Day: 124		Total: 47878 Buying: ['BSRR']
# Day: 125		Total: 47751 Buying: ['SBNY']
# Day: 126		Total: 47667 Buying: ['VMBS']
# Day: 127		Total: 47414 Buying: ['VGSH']
# Day: 128		Total: 47461 Buying: ['VGSH']
# Day: 129		Total: 47481 Buying: ['VGSH']
# Day: 130		Total: 47507 Buying: ['VGSH']
# Day: 131		Total: 47522 Buying: ['VGSH']
# Day: 132		Total: 47542 Buying: ['VGSH']
# Day: 133		Total: 47552 Buying: ['VGSH']
# Day: 134		Total: 47560 Buying: ['VCSH']
# Day: 135		Total: 47555 Buying: ['VGSH']
# Day: 136		Total: 47558 Buying: ['VGSH']
# Day: 137		Total: 47558 Buying: ['VGSH']
# Day: 138		Total: 47564 Buying: ['VGSH']
# Day: 139		Total: 47564 Buying: ['VGSH']
# Day: 140		Total: 47568 Buying: ['VGSH']
# Day: 141		Total: 47568 Buying: ['VGSH']
# Day: 142		Total: 47568 Buying: ['VCSH']
# Day: 143		Total: 47556 Buying: ['VTIP']
# Day: 144		Total: 47555 Buying: ['LNCE']
# Day: 145		Total: 47555 Buying: ['VGSH']
# Day: 146		Total: 47738 Buying: ['VGSH']
# Day: 147		Total: 47758 Buying: ['VGSH']
# Day: 148		Total: 47780 Buying: ['VGSH']
# Day: 149		Total: 47803 Buying: ['VGSH']
# Day: 150		Total: 47817 Buying: ['VGSH']
# Day: 151		Total: 47822 Buying: ['VGSH']
# Day: 152		Total: 47822 Buying: ['VGSH']
# Day: 153		Total: 47822 Buying: ['VCSH']
# Day: 154		Total: 47806 Buying: ['VTIP']
# Day: 155		Total: 47791 Buying: ['VMBS']
# Day: 156		Total: 47781 Buying: ['OTEX']
# Day: 157		Total: 47777 Buying: ['VGSH']
# Day: 158		Total: 47887 Buying: ['VCSH']
# Day: 159		Total: 47885 Buying: ['VTIP']
# Day: 160		Total: 47870 Buying: ['VMBS']
# Day: 161		Total: 47838 Buying: ['GBDC']
# Day: 162		Total: 47807 Buying: ['VGSH']
# Day: 163		Total: 47822 Buying: ['VCSH']
# Day: 164		Total: 47806 Buying: ['VTIP']
# Day: 165		Total: 47802 Buying: ['VGSH']
# Day: 166		Total: 47818 Buying: ['VGSH']
# Day: 167		Total: 47828 Buying: ['VGSH']
# Day: 168		Total: 47838 Buying: ['VGSH']
# Day: 169		Total: 47854 Buying: ['VGSH']
# Day: 170		Total: 47881 Buying: ['VGSH']
# Day: 171		Total: 47897 Buying: ['VGSH']
# Day: 172		Total: 47905 Buying: ['VGSH']
# Day: 173		Total: 47914 Buying: ['VGSH']
# Day: 174		Total: 47918 Buying: ['VCSH']
# Day: 175		Total: 47913 Buying: ['VCSH']
# Day: 176		Total: 47909 Buying: ['VTIP']
# Day: 177		Total: 47903 Buying: ['VGSH']
# Day: 178		Total: 47917 Buying: ['VGSH']
# Day: 179		Total: 47924 Buying: ['GBDC']
# Day: 180		Total: 47918 Buying: ['VCSH']
# Day: 181		Total: 47790 Buying: ['VTIP']
# Day: 182		Total: 47785 Buying: ['VGSH']
# Day: 183		Total: 47795 Buying: ['VGSH']
# Day: 184		Total: 47780 Buying: ['GBDC']
# Day: 185		Total: 47780 Buying: ['VCSH']
# Day: 186		Total: 47471 Buying: ['VTIP']
# Day: 187		Total: 47463 Buying: ['VMBS']
# Day: 188		Total: 47429 Buying: ['VGSH']
# Day: 189		Total: 47431 Buying: ['VCSH']
# Day: 190		Total: 47426 Buying: ['VGSH']
# Day: 191		Total: 47441 Buying: ['VCSH']
# Day: 192		Total: 47439 Buying: ['VGSH']
# Day: 193		Total: 47449 Buying: ['VGSH']
# Day: 194		Total: 47454 Buying: ['VGSH']
# Day: 195		Total: 47459 Buying: ['VGSH']
# Day: 196		Total: 47461 Buying: ['VGSH']
# Day: 197		Total: 47469 Buying: ['VCSH']
# Day: 198		Total: 47464 Buying: ['VGSH']
# Day: 199		Total: 47474 Buying: ['VCSH']
# Day: 200		Total: 47472 Buying: ['VTIP']
# Day: 201		Total: 47465 Buying: ['VTIP']
# Day: 202		Total: 47455 Buying: ['VMBS']
# Day: 203		Total: 47453 Buying: ['RUTH']
# Day: 204		Total: 47382 Buying: ['VCIT']
# Day: 205		Total: 47174 Buying: ['SLGN']
# Day: 206		Total: 47137 Buying: ['SYKE']
# Day: 207		Total: 47036 Buying: ['VGSH']
# Day: 208		Total: 47157 Buying: ['VGSH']
# Day: 209		Total: 47168 Buying: ['VGSH']
# Day: 210		Total: 47178 Buying: ['VGSH']
# Day: 211		Total: 47195 Buying: ['VGSH']
# Day: 212		Total: 47203 Buying: ['VGSH']
# Day: 213		Total: 47211 Buying: ['VGSH']
# Day: 214		Total: 47221 Buying: ['VGSH']
# Day: 215		Total: 47229 Buying: ['VGSH']
# Day: 216		Total: 47229 Buying: ['VCSH']
# Day: 217		Total: 47222 Buying: ['VGSH']
# Day: 218		Total: 47229 Buying: ['VGSH']
# Day: 219		Total: 47232 Buying: ['VGSH']
# Day: 220		Total: 47235 Buying: ['VGSH']
# Day: 221		Total: 47239 Buying: ['VGSH']
# Day: 222		Total: 47245 Buying: ['VCSH']
# Day: 223		Total: 47235 Buying: ['VGSH']
# Day: 224		Total: 47239 Buying: ['VCSH']
# Day: 225		Total: 47232 Buying: ['HSIC']
# Day: 226		Total: 47223 Buying: ['HSIC']
# Day: 227		Total: 46821 Buying: ['VTIP']
# Day: 228		Total: 46281 Buying: ['VGSH']
# Day: 229		Total: 46301 Buying: ['VGSH']
# Day: 230		Total: 46310 Buying: ['VGSH']
# Day: 231		Total: 46318 Buying: ['VGSH']
# Day: 232		Total: 46325 Buying: ['VGSH']
# Day: 233		Total: 46325 Buying: ['VGSH']
# Day: 234		Total: 46333 Buying: ['VGSH']
# Day: 235		Total: 46337 Buying: ['VGSH']
# Day: 236		Total: 46345 Buying: ['VGSH']
# Day: 237		Total: 46351 Buying: ['VGSH']
# Day: 238		Total: 46363 Buying: ['VCSH']
# Day: 239		Total: 46358 Buying: ['VGSH']
# Day: 240		Total: 46363 Buying: ['VCSH']
# Day: 241		Total: 46361 Buying: ['VGSH']
# Day: 242		Total: 46381 Buying: ['VGSH']
# Day: 243		Total: 46383 Buying: ['VGSH']
# Day: 244		Total: 46391 Buying: ['VCSH']
# Day: 245		Total: 46383 Buying: ['VTIP']
# Day: 246		Total: 46379 Buying: ['VGSH']
# Day: 247		Total: 46395 Buying: ['VGSH']
# Day: 248		Total: 46398 Buying: ['VGSH']
# Day: 249		Total: 46400 Buying: ['VGSH']
# Day: 250		Total: 46407 Buying: ['VCSH']
# Day: 251		Total: 46398 Buying: ['VTIP']
# Day: 252		Total: 46393 Buying: ['VMBS']
# Day: 253		Total: 46385 Buying: ['VCIT']
# Day: 254		Total: 46351 Buying: ['GNCMA']
# Day: 255		Total: 46323 Buying: ['EA']
# Day: 256		Total: 46022 Buying: ['VGSH']
# Day: 257		Total: 46084 Buying: ['VCSH']
# Day: 258		Total: 46074 Buying: ['VTIP']
# Day: 259		Total: 46069 Buying: ['VMBS']
# Day: 260		Total: 46065 Buying: ['VGSH']
# Day: 261		Total: 46069 Buying: ['VGSH']
# Day: 262		Total: 46070 Buying: ['VGSH']
# Day: 263		Total: 46074 Buying: ['VCSH']
# Day: 264		Total: 46073 Buying: ['VTIP']
# Day: 265		Total: 46057 Buying: ['VMBS']
# Day: 266		Total: 46049 Buying: ['VCIT']
# Day: 267		Total: 46047 Buying: ['EA']
# Day: 268		Total: 46028 Buying: ['VGSH']
# Day: 269		Total: 46199 Buying: ['VCSH']
# Day: 270		Total: 46194 Buying: ['VGSH']
# Day: 271		Total: 46198 Buying: ['VGSH']
# Day: 272		Total: 46195 Buying: ['VTIP']
# Day: 273		Total: 46193 Buying: ['VCSH']
# Day: 274		Total: 46201 Buying: ['VCSH']
# Day: 275		Total: 46202 Buying: ['VGSH']
# Day: 276		Total: 46198 Buying: ['VTIP']
# Day: 277		Total: 46189 Buying: ['VMBS']
# Day: 278		Total: 46171 Buying: ['VCIT']
# Day: 279		Total: 46131 Buying: ['QQXT']
# Day: 280		Total: 46117 Buying: ['WNEB']
# Day: 281		Total: 46026 Buying: ['WNEB']
# Day: 282		Total: 46026 Buying: ['BFIN']
# Day: 283		Total: 45842 Buying: ['VCSH']
# Day: 284		Total: 45921 Buying: ['VCSH']
# Day: 285		Total: 45921 Buying: ['VCSH']
# Day: 286		Total: 45929 Buying: ['VGSH']
# Day: 287		Total: 45912 Buying: ['VTIP']
# Day: 288		Total: 45907 Buying: ['VCSH']
# Day: 289		Total: 45919 Buying: ['VGSH']
# Day: 290		Total: 45896 Buying: ['BOBE']
# Day: 291		Total: 45885 Buying: ['VCSH']
# Day: 292		Total: 45916 Buying: ['VGSH']
# Day: 293		Total: 45907 Buying: ['BOBE']
# Day: 294		Total: 45904 Buying: ['VCSH']
# Day: 295		Total: 45938 Buying: ['BOBE']
# Day: 296		Total: 45909 Buying: ['BOBE']
# Day: 297		Total: 45923 Buying: ['BOBE']
# Day: 298		Total: 45964 Buying: ['BOBE']
# Day: 299		Total: 45978 Buying: ['BOBE']
# Day: 300		Total: 45993 Buying: ['BOBE']
# Day: 301		Total: 46011 Buying: ['BOBE']
# Day: 302		Total: 46029 Buying: ['BSFT']
# Day: 303		Total: 46026 Buying: ['BOBE']
# Day: 304		Total: 46044 Buying: ['BSFT']
# Day: 305		Total: 46043 Buying: ['BOBE']
# Day: 306		Total: 46080 Buying: ['BOBE']

# %%
GP.save_results()
GP.display_graph()
# Out:
# interactive(children=(SelectMultiple(description='Strategies', index=(0,), layout=Layout(width='50%'), options…

# %%
# Testing RLF on example stocks
def rlf(y_actual, y_pred):
    
    '''Code is modified so that both vectors are clearly 1 dimension'''
    # Slice the final predicted time step from the actual value
    y_slice = y_actual
    
    # Make sure that casting is correct
    y_slice = tf.cast(y_slice, dtype=tf.float32)
    y_pred = tf.cast(y_pred, dtype=tf.float32)
    
    # Calculate return ratio
    return_ratio = tf.math.divide(tf.math.subtract(y_pred, y_slice), y_slice)
    
    # Create an array of all_ones so that we can calculate all permutations of subtractions
    all_ones = tf.ones([y_slice.shape[0], 1])

    # Creates a N x N matrix with every predicted return ratio for each company subtracted with every other
    # company
    pred_dif = tf.math.subtract(
        tf.matmul(return_ratio, all_ones, transpose_b=True),
        tf.matmul(all_ones, return_ratio, transpose_b=True)
    )
    
    print(pred_dif)

    # Creates an N x N matrix containing every actual return ratio for each company subtracted with every other
    # company By switching the order of the all_ones matricies and the actual prices, a negative sign is introduced
    # When RELU is applied later, correct predictions will not affect loss while incorrect predictions will affect
    # loss depending on how incorrect the prediction was
    actual_dif = tf.math.subtract(
        tf.matmul(all_ones, y_slice, transpose_b=True),
        tf.matmul(y_slice, all_ones, transpose_b=True)
    )
    
    print(actual_dif)

    # Using the above two qualities, the algorithm can be punished for incorrectly calculating when a company is
    # doing better than another company Reduces the mean across each dimension until only 1 value remains
    rank_loss = tf.reduce_mean(
        # Takes if a given value is >0, it is kept, otherwise, it becomes 0
        tf.nn.relu(
            tf.multiply(pred_dif, actual_dif)
        )
    )
    print(tf.multiply(pred_dif, actual_dif))
    print(rank_loss)

# %%
import numpy as np

# Create numpy arrays to mimic the entity column ouput

pred = np.array([5, 1, 5])
actual = np.array([5, 1, 1])


pred = np.reshape(pred, (pred.shape[0],1))
actual = np.reshape(actual, (actual.shape[0],1))

rlf(actual, pred)

# %%
y_actual = np.array([1, 2, 3, 4, 5])
y_actual = np.reshape(y_actual, (y_actual.shape[0], 1))

y_1 = y_actual[:, -1:]
y_2 = y_actual[:, -2:]
